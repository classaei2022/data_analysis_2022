# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import linregress
import matplotlib.pyplot as plt
from IPython.display import Image
Image(filename='ANALYSE DES DONNEES EN PYTHON.jpg')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# In data mining, **Exploratory Data Analysis (EDA)** is an approach to analyzing datasets to summarize their main characteristics, often with visual methods. EDA is used for seeing **what the data can tell us** before the modeling task.

# %%
df = pd.read_excel('Dataset_Mall_Customers.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df
# Out:
#      Customer ID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0              1  Female   20                  14                      43
# 1              2  Female   19                  14                      82
# 2              3    Male   25                  16                      12
# 3              4    Male   23                  17                      80
# 4              5  Female   21                  17                      45
# ..           ...     ...  ...                 ...                     ...
# 195          196  Female   40                 120                      29
# 196          197  Female   49                 125                      79
# 197          198  Female   31                 129                      76
# 198          199    Male   42                 130                      17
# 199          200    Male   32                 135                      82
#
# [200 rows x 5 columns]

# %%
df.mean()
# Out:
# Customer ID               100.500
# Age                        38.705
# Annual Income (k$)         60.505
# Spending Score (1-100)     50.710
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
F"{len(df)} entries and {len(df.columns)} columns"
# Out:
# '200 entries and 5 columns'

# %% [markdown]
# ### Linear Regression
# The equation for the straight line that describes linear regression is **y = mx + b**, where m is the slope and b is the intercept.
# Linear regression attempts to model the relationship between two variables by fitting a linear equation to observed data. One variable is considered to be an **explanatory variable**, and the other is considered to be a **dependent variable**.

# %%
x = df['Annual Income (k$)']
y = df['Spending Score (1-100)']

stats = linregress(x, y)

m = stats.slope
b = stats.intercept

plt.scatter(x, y)
plt.plot(x, m * x + b, color="red")

plt.title("Spending Score variation / Annual Income v")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")

plt.show()

# %% [markdown]
# ### Correlation Matrix
#
# Pair Plots, it is difficult to see the relation between three numerical variables in a single graph. In those cases, we’ll use the correlation matrix.

# %%
sns.heatmap(df[['Age','Annual Income (k$)','Spending Score (1-100)']].corr(), annot=True, cmap = 'Blues')
plt.show()

# %%
plt.scatter(df['Age'], df['Annual Income (k$)'])

plt.title("Annual Income by Age")
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
plt.show()

# %%
x = df['Age']
y = df['Annual Income (k$)']

stats = linregress(x, y)

m = stats.slope
b = stats.intercept

plt.scatter(x, y)
plt.plot(x, m * x + b, color="red")

plt.show()

# %%
df['Gender'].value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# 'Merci'
